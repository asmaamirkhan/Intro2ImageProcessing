# %%
# import libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# %%
# file uploader
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cd6885a-b140-4b14-b047-b79013513661" name="files[]" multiple disabled />
#      <output id="result-6cd6885a-b140-4b14-b047-b79013513661">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pass.jpg to pass.jpg

# %%
def detectFaces(imgPath):
  # open classifier
  haar = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
  
  # open image and store its RGB and GRAY
  image = cv2.imread(imgPath)
  rgbImg = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

  # find faces
  faces = haar.detectMultiScale(gray, scaleFactor=1.15, minNeighbors=5)
  
  # draw rectangles
  for (x,y,z,w) in faces:
    cv2.rectangle(rgbImg, (x,y), (x+z,y+w), (0,256,256), 10)
  
  # show image
  print('Number of detected faces:', len(faces))
  plt.imshow(rgbImg)

# %%
detectFaces('kids-playing.jpg')
# Out:
# Number of detected faces: 7

# %%
detectFaces('happy-kids_mini.jpg')
# Out:
# Number of detected faces: 3

# %%
detectFaces('kids.jpg')
# Out:
# Number of detected faces: 4

# %%
detectFaces('kids-school.jpg')
# Out:
# Number of detected faces: 5

# %%
detectFaces('passengers.jpg')
# Out:
# Number of detected faces: 9

# %%
detectFaces('pass.jpg')
# Out:
# Number of detected faces: 4
